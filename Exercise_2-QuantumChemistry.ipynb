# %% [markdown]
# # Exercise 2: Quantum Chemistry with VQE
#
# ## Introduction
#
# In this exercise, you will learn how to apply the **Variational Quantum Eigensolver (VQE)** algorithm to compute the ground state energy of a physical system described by the **Transverse-field Ising model**.
#
# The transverse-field Ising model is a mathematical model in statistical mechanics that features a lattice with nearest neighbour interactions determined by the alignment or anti-alignment of spin projections along the $z$ axis, as well as an external magnetic field perpendicular to the $z$ axis (without loss of generality, along the $x$ axis).
#
# ### Learning Objectives
#
# By the end of this exercise, you will be able to:
# 1. Set up a quantum Hamiltonian for the Ising model
# 2. Implement the VQE algorithm using Qiskit
# 3. Compare quantum results with classical solutions
# 4. Visualize the ground state energy as a function of the external field

# %% [markdown]
# ## Step 1: Install Dependencies
#
# First, let's install all the needed dependencies. Run the cell below to install the required packages.
#
# **Note:** This notebook is compatible with Qiskit 2.4.1 and tested on Python 3.13.7.

# %%
# Install packages in the current Jupyter kernel

import sys
# !{sys.executable} -m pip install qiskit==2.4.1
# !{sys.executable} -m pip install qiskit-aer==0.17.2
# !{sys.executable} -m pip install qiskit-algorithms==0.4.0
# !{sys.executable} -m pip install qiskit-ibm-runtime==0.47.0
# !{sys.executable} -m pip install pylatexenc

# %% [markdown]
# ## Step 2: Basic Imports
#
# Import the basic libraries we'll need throughout this exercise.

# %%
# TODO: Import numpy as np
# TODO: Import matplotlib.pyplot as plt
# TODO: Import qiskit and print the version

# Your code here:

# %% [markdown]
# ## Step 3: Connect to Quantum Services
#
# Now we'll connect to IBM Quantum services. You'll need your API token and instance information.
#
# **Important:** Replace the token and instance with your own credentials!

# %%
# TODO: Import QiskitRuntimeService from qiskit_ibm_runtime
# TODO: Set channel to "ibm_cloud" or "ibm_quantum"
# TODO: Create a service instance with your token and instance

# Your code here:

# %% [markdown]
# ## Step 4: Select Backend
#
# List available backends and select one for execution. For this exercise, we'll use the simulator.

# %%
# TODO: List all available backends
# TODO: Print the backend names

# Your code here:

# %%
# TODO: Import AerSimulator from qiskit_aer
# TODO: Set run_target to 'simulator'
# TODO: Create backend based on run_target
# TODO: Print appropriate warning message

# Your code here:

# %% [markdown]
# ## Step 5: Problem Definition
#
# ### The Transverse-field Ising Model
#
# In the Transverse-field Ising model, each site can have a spin that can be in one of two states: either +1 (spin-up) or -1 (spin-down).
#
# The Hamiltonian is given by:
#
# $H = -J \sum_{<i,j>}{S_i S_j} + b\sum_i S_i$
#
# Where:
# - $J$ is the interaction strength between neighboring spins
# - $<i,j>$ are the nearest neighbors
# - $S_i$ is the spin at site $i$
# - $b$ is the relative strength of the external field
#
# For a simple 2-spins system:
#
# $H = -J S_1 S_2 + b(S_1 + S_2)$
#
# ### Your Task
#
# Set up the observables and Hamiltonian for this system.

# %%
# TODO: Import SparsePauliOp from qiskit.quantum_info
# TODO: Define observables_labels as ["ZZ", "IX", "XI"]
# TODO: Create observables list using SparsePauliOp for each label
# TODO: Set J = 1, num_qubits = 2
# TODO: Create b_list using np.linspace(0, 4, 10)
# TODO: Define Hamiltonian function that takes J, b, and observables
#       and returns H = -J*(observables[0]) + b*(observables[1] + observables[2])

# Your code here:

# %% [markdown]
# ## Step 6: Classical Solution for Benchmarking
#
# Before implementing the quantum solution, let's compute the exact solution classically. This will serve as a benchmark for our VQE results.

# %%
# TODO: Import linalg from numpy
# TODO: Initialize empty lists: E_l, P_l, energy_levels
# TODO: Loop through b_list:
#       - Create Hamiltonian H for each b value
#       - Convert to matrix using H.to_matrix()
#       - Compute eigenvalues using linalg.eigh
#       - Append ground state energy to E_l
#       - Append all eigenvalues to energy_levels

# Your code here:

# %% [markdown]
# ## Step 7: Quantum Solution with VQE
#
# Now we'll implement the VQE algorithm to find the ground state energy.
#
# ### VQE Overview
#
# VQE is a hybrid quantum-classical algorithm that:
# 1. Prepares a parameterized quantum state (ansatz)
# 2. Measures the energy expectation value
# 3. Uses a classical optimizer to update parameters
# 4. Repeats until convergence
#
# ### Step 7a: Create the Ansatz

# %%
# TODO: Import TwoLocal from qiskit.circuit.library
# TODO: Create ansatz using TwoLocal with:
#       - num_qubits qubits
#       - rotation_blocks=['ry', 'rz']
#       - entanglement_blocks='cx'
#       - entanglement='linear'
#       - reps=1
# TODO: Draw the ansatz circuit

# Your code here:

# %% [markdown]
# ### Step 7b: Transpile for the Backend

# %%
# TODO: Import transpile from qiskit
# TODO: Transpile the ansatz for the backend with optimization_level=3
# TODO: Draw the transpiled circuit

# Your code here:

# %% [markdown]
# ### Step 7c: Set Up the Estimator

# %%
# TODO: Import Estimator from qiskit.primitives or qiskit_ibm_runtime
# TODO: Create estimator instance based on backend type

# Your code here:

# %% [markdown]
# ### Step 7d: Define the Cost Function
#
# The cost function evaluates the energy for given parameters.

# %%
# TODO: Create a dictionary to store optimization history
# TODO: Define cost_fn(params, ansatz, hamiltonian, estimator) that:
#       - Runs estimator with ansatz, hamiltonian, and params
#       - Extracts energy value from result
#       - Updates cost_history_dict
#       - Prints progress every 10 iterations
#       - Returns energy

# Your code here:

# %% [markdown]
# ### Step 7e: Run the Optimization
#
# Now we'll run VQE for each value of the external field b.

# %%
# TODO: Import minimize from scipy.optimize
# TODO: Initialize lists for ground_state_energies_simulator and _hardware
# TODO: Loop through b_list:
#       - Create Hamiltonian and apply layout
#       - Generate random initial parameters
#       - Run minimize with cost_fn, method="COBYLA"
#       - Store results in appropriate list

# Your code here:

# %% [markdown]
# ## Step 8: Plot Results
#
# Finally, let's visualize our results and compare them with the classical solution.

# %%
# TODO: Create a figure with subplots
# TODO: Set labels and title
# TODO: Plot classical energy levels in gray
# TODO: Scatter plot VQE results in blue
# TODO: If hardware results exist, plot them in green
# TODO: Add legend and show plot

# Your code here:

# %% [markdown]
# ## Step 9: Analyze Optimization Process
#
# Let's examine how the optimization converged.

# %%
# TODO: Plot the cost history showing convergence
# TODO: Set appropriate labels and title

# Your code here:

# %% [markdown]
# ## Conclusion
#
# Congratulations! You have successfully:
# 1. ✅ Set up a quantum Hamiltonian for the Ising model
# 2. ✅ Implemented the VQE algorithm
# 3. ✅ Compared quantum and classical results
# 4. ✅ Visualized the ground state energy
#
# ### Questions to Consider
#
# 1. How well does the VQE solution match the classical solution?
# 2. What happens to the ground state energy as the external field increases?
# 3. How many iterations did the optimizer need to converge?
# 4. What could you do to improve the accuracy of the VQE results?
#
# ### Next Steps
#
# Try modifying the exercise:
# - Change the number of qubits
# - Use a different ansatz
# - Adjust the optimizer parameters
# - Run on real quantum hardware
