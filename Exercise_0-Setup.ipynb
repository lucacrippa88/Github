# %% [markdown]
# # Exercise 0: Environment Setup
#
# **Objective:** Learn how to set up your environment to access IBM Quantum computers and understand the differences between IBM Quantum Platform and IBM Cloud Platform.
#
# ---
#
# ## Introduction
#
# In this exercise, you will:
# 1. Install the necessary Qiskit packages
# 2. Import basic libraries
# 3. Set up access to IBM Quantum computers
# 4. List available backends
# 5. Configure your runtime environment
#
# ### Platforms
#
# - **IBM Quantum Platform:** https://quantum.ibm.com
# - **IBM Cloud Platform:** https://quantum.cloud.ibm.com
#
# ---

# %% [markdown]
# ## Part 1: Install Dependencies
#
# **Task:** Install the required Qiskit packages.
#
# You need to install:
# - `qiskit==2.4.1`
# - `qiskit-aer==0.17.2`
# - `qiskit-algorithms==0.4.0`
# - `qiskit-ibm-runtime==0.47.0`
#
# **Hint:** Use `!{sys.executable} -m pip install <package>==<version>` to install packages in the current Jupyter kernel.
#
# **Note:** This notebook is tested on Python 3.13.7.

# %%
# TODO: Import sys module

# TODO: Install qiskit==2.4.1

# TODO: Install qiskit-aer==0.17.2

# TODO: Install qiskit-algorithms==0.4.0

# TODO: Install qiskit-ibm-runtime==0.47.0

# %% [markdown]
# ## Part 2: Basic Imports
#
# **Task:** Import the basic libraries needed for quantum computing.
#
# Import the following:
# - `numpy` as `np`
# - `matplotlib.pyplot` as `plt`
# - `qiskit`
#
# Then print the Qiskit version you're using.

# %%
# TODO: Import numpy as np

# TODO: Import matplotlib.pyplot as plt

# TODO: Import qiskit

# TODO: Print the Qiskit version using qiskit.__version__

# %% [markdown]
# ## Part 3: Setup Access to IBM Quantum Computers
#
# **Task:** Configure access to IBM Quantum services.
#
# 1. Import `QiskitRuntimeService` from `qiskit_ibm_runtime`
# 2. Set the channel variable (either `"ibm_quantum"` or `"ibm_cloud"`)
# 3. Create a service instance with:
#    - `channel`: your chosen channel
#    - `token`: your IBM Cloud API key or IBM Quantum token
#    - `instance`: your IBM Cloud CRN (only needed for IBM Cloud)
#
# **Note:** You'll need to get your credentials from:
# - IBM Quantum Platform: https://quantum.ibm.com (for `ibm_quantum` channel)
# - IBM Cloud: https://quantum.cloud.ibm.com (for `ibm_cloud` channel)
#
# **Security Reminder:** Never share your API keys or tokens publicly!

# %%
# TODO: Import QiskitRuntimeService from qiskit_ibm_runtime

# TODO: Set the channel variable ("ibm_cloud")

# TODO: Create a QiskitRuntimeService instance
# For ibm_cloud: service = QiskitRuntimeService(channel=channel, token='YOUR_TOKEN', instance='YOUR_CRN')

# %% [markdown]
# ## Part 4: List Available Backends
#
# **Task:** Retrieve and display all available quantum backends.
#
# 1. Use `service.backends()` to get all available backends
# 2. Print the names of all backends
#
# **Hint:** You can use a list comprehension to extract backend names: `[backend.name for backend in backends]`

# %%
# TODO: Get all available backends using service.backends()

# TODO: Print the list of backend names

# %% [markdown]
# ## Part 5: Configure Runtime Environment
#
# **Task:** Set up your backend configuration for running quantum circuits.
#
# 1. Import `AerSimulator` from `qiskit_aer`
# 2. Set the `run_target` variable to one of:
#    - `'simulator'`: Use local Aer simulator (free and fast)
#    - `'least_busy'`: Use the least busy real quantum computer
#    - A specific backend name from the list above
# 3. Implement the logic to select the appropriate backend based on `run_target`
# 4. Add warning messages for real hardware usage
#
# **Important Notes:**
# - Using real quantum hardware consumes credits/minutes
# - IBM Quantum Platform (Open plan): consumes minutes
# - IBM Cloud (Pay-as-you-go): ~$1.6 per second of quantum time
# - Start with the simulator for learning!

# %%
# TODO: Import AerSimulator from qiskit_aer

# TODO: Set run_target to 'simulator', 'least_busy', or a specific backend name

# TODO: Implement conditional logic to select the backend
# If run_target is 'simulator': backend = AerSimulator()
# If run_target is 'least_busy': backend = service.least_busy(operational=True, simulator=False)
# Otherwise: backend = service.backend(run_target)

# TODO: Add warning messages based on channel and run_target
# If using ibm_quantum channel and not simulator: warn about consuming Open plan minutes
# If using ibm_cloud channel and not simulator: warn about consuming credits (~$1.6/second)
# If using simulator: inform that it's a quick local simulation

# %% [markdown]
# ## Congratulations!
#
# If you've completed all the steps above successfully, you now have:
# - ✅ Installed all necessary Qiskit packages
# - ✅ Set up access to IBM Quantum computers
# - ✅ Configured your runtime environment
#
# You're ready to start programming quantum computers! 🎉
#
# ---
#
# ## Reflection Questions
#
# 1. What is the difference between IBM Quantum Platform and IBM Cloud Platform?
# 2. Why might you choose to use a simulator instead of real quantum hardware?
# 3. What are the cost implications of running circuits on real quantum hardware?
# 4. How can you find the least busy quantum computer?
#
# ---
#
# ## Next Steps
#
# Now that your environment is set up, you can:
# - Create your first quantum circuit
# - Run simulations locally
# - Submit jobs to real quantum hardware (when ready)
# - Explore quantum algorithms
#
# Happy quantum computing! 🚀
